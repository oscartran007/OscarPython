# %% [markdown]
# # Toán tử

# %% [markdown]
# ## Toán tử cộng

# %% [markdown]
# # Kiểu Dữ Liệu

# %%
print("My name is Dy") # String -> str
# Out:
# My name is Dy

# %%
print(101) # integer -> int
# Out:
# 101

# %%
print(10.05) #floot -> floot
# Out:
# 10.05

# %%
print(true)  #boolean -> boolaa
print(false)

# %% [markdown]
# ## Toán tử

# %%
a = 10 
b = 5
c = 2.5
d = 'Python'
e = 'Fundamental'

# %% [markdown]
# ## Toán tử nhân

# %% [markdown]
# # Toán tử cộng

# %%
print(a+b)
print(a+c)
# Out:
# 15
# 12.5

# %%
print(d + e)
# Out:
# PythonFundamental

# %%
print(a + True) # True = 1
print(a + False) # False = 0
# Out:
# 11
# 10

# %% [markdown]
# # Toán tử trừ

# %%
print (c - a)
# Out:
# -7.5

# %%
print(d - e)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(d - e)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# ## Toán tử nhân

# %%
print(b * c)
# Out:
# 12.5

# %%
print(d*3)
# Out:
# PythonPythonPython

# %% [markdown]
# # Toán tử chia

# %%
print(a / b) # Kết quả của phép chia luôn là float
# Out:
# 2.0

# %% [markdown]
# ## Chia lấy dư

# %%
print(b % 2)
print(b // 2) # Kết quả của phép chia lấy phần nguyên là int
# Out:
# 1

# %% [markdown]
# ## Lũy thừa

# %%
print(2 ** 3)
# Out:
# 8

# %% [markdown]
# ## Toán tử quan hệ

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 5
y = 4
z = 9

# %%
x > y
# Out:
# True

# %%
x ** 2 <= z
# Out:
# False

# %%
(x ** 2 - z) ** 0.5 == y
# Out:
# True

# %%
x + y + (x < y) - 1 <= z
# Out:
# True

# %%
x * y - z <= (z ** 2 +40) ** 0.5
# Out:
# True

# %% [markdown]
# ## Phép gán

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Toán tử logic

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:5c626946-d91c-4345-9d70-8b01862846b6.png)![image.png](attachment:adac4f27-4df0-4ba1-b1c4-2f913b26403d.png)
